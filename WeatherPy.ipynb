# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json 
import time
from scipy.stats import linregress

from api_keys import weather_api_key

from citipy import citipy

# %%
latLngs=[]
cities=[]

latRange=(-90,90)
lngRange=(-180,180)

lats=np.random.uniform(latRange[0],latRange[1], size=1500) #what does this size 1500 mean
lons=np.random.uniform(lngRange[0],lngRange[1],size=1500)
latsLons=zip(lats,lons)

for latLon in latsLons:
    city= citipy.nearest_city(latLon[0],latLon[1]).city_name
    
    if city not in cities:
        cities.append(city)
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 635

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
cityList = []
print("Beginning Data Retrieval     ")
print("-----------------------------")
recordCount = 1
setCount = 1
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        setCount += 1
        recordCount = 0
    cityURL = url + "&q=" + city
    print("Processing Record %s of Set %s | %s" % (recordCount, setCount, city))
    recordCount += 1
    try:
        response = requests.get(cityURL).json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response["coord"]["lat"]
        city_lng = response["coord"]["lon"]
        city_max_temp = response["main"]["temp_max"]
        city_humidity = response["main"]["humidity"]
        city_clouds = response["clouds"]["all"]
        city_wind = response["wind"]["speed"]
        city_country = response["sys"]["country"]
        city_date = response["dt"]
        cityList.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    except:
        print("City not found. Skipping...")
        pass
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mae hong son
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | beira
# Processing Record 5 of Set 1 | port hedland
# Processing Record 6 of Set 1 | port alfred
# Processing Record 7 of Set 1 | fukue
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | guerrero negro
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | folkestone
# Processing Record 14 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 1 | chardara
# Processing Record 16 of Set 1 | lompoc
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | novyy urengoy
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | salalah
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | novyy urgal
# Processing Record 23 of Set 1 | lakatoro
# Processing Record 24 of Set 1 | leh
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | yumen
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | baena
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | huainan
# Processing Record 33 of Set 1 | port elizabeth
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | nikolskoye
# Processing Record 37 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 1 | lavrentiya
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | praia da vitoria
# Processing Record 45 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 1 | atbasar
# Processing Record 47 of Set 1 | broome
# Processing Record 48 of Set 1 | chicama
# Processing Record 49 of Set 1 | exeter
# Processing Record 50 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 0 of Set 2 | chuguyevka
# Processing Record 1 of Set 2 | ixtapa
# Processing Record 2 of Set 2 | cape town
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | neuquen
# Processing Record 7 of Set 2 | catamarca
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | doka
# Processing Record 10 of Set 2 | gudur
# Processing Record 11 of Set 2 | rey bouba
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | acapulco
# Processing Record 15 of Set 2 | mahibadhoo
# Processing Record 16 of Set 2 | geraldton
# Processing Record 17 of Set 2 | erenhot
# Processing Record 18 of Set 2 | san patricio
# Processing Record 19 of Set 2 | nabire
# Processing Record 20 of Set 2 | kandiari
# Processing Record 21 of Set 2 | hailey
# Processing Record 22 of Set 2 | mar del plata
# Processing Record 23 of Set 2 | owando
# Processing Record 24 of Set 2 | tecolutla
# Processing Record 25 of Set 2 | tautira
# Processing Record 26 of Set 2 | xuanhua
# Processing Record 27 of Set 2 | amparafaravola
# Processing Record 28 of Set 2 | omboue
# Processing Record 29 of Set 2 | rio gallegos
# Processing Record 30 of Set 2 | saint-pierre
# Processing Record 31 of Set 2 | punta alta
# Processing Record 32 of Set 2 | kavieng
# Processing Record 33 of Set 2 | careva cuprija
# Processing Record 34 of Set 2 | melita
# Processing Record 35 of Set 2 | zyryanka
# Processing Record 36 of Set 2 | torbay
# Processing Record 37 of Set 2 | puerto ayora
# Processing Record 38 of Set 2 | hami
# Processing Record 39 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 2 | french harbor
# Processing Record 41 of Set 2 | arkhangelsk
# Processing Record 42 of Set 2 | saint-augustin
# Processing Record 43 of Set 2 | hamilton
# Processing Record 44 of Set 2 | bowen
# Processing Record 45 of Set 2 | mount isa
# Processing Record 46 of Set 2 | namatanai
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | vavoua
# Processing Record 49 of Set 2 | punta arenas
# Processing Record 0 of Set 3 | takab
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 3 | marienburg
# Processing Record 6 of Set 3 | luderitz
# Processing Record 7 of Set 3 | shingu
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | rassvet
# Processing Record 10 of Set 3 | cartagena del chaira
# Processing Record 11 of Set 3 | port hardy
# Processing Record 12 of Set 3 | porto novo
# Processing Record 13 of Set 3 | la primavera
# Processing Record 14 of Set 3 | svetlyy
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | maniitsoq
# Processing Record 18 of Set 3 | komsomolskiy
# Processing Record 19 of Set 3 | emet
# Processing Record 20 of Set 3 | aklavik
# Processing Record 21 of Set 3 | westport
# Processing Record 22 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | vanimo
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | gat
# Processing Record 27 of Set 3 | strelka
# Processing Record 28 of Set 3 | korla
# Processing Record 29 of Set 3 | sulangan
# Processing Record 30 of Set 3 | montlucon
# Processing Record 31 of Set 3 | leningradskiy
# Processing Record 32 of Set 3 | hobart
# Processing Record 33 of Set 3 | vardo
# Processing Record 34 of Set 3 | jamestown
# Processing Record 35 of Set 3 | kloulklubed
# Processing Record 36 of Set 3 | caravelas
# Processing Record 37 of Set 3 | butaritari
# Processing Record 38 of Set 3 | kirakira
# Processing Record 39 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | cabo san lucas
# Processing Record 42 of Set 3 | mildura
# Processing Record 43 of Set 3 | samarinda
# Processing Record 44 of Set 3 | airai
# Processing Record 45 of Set 3 | bogatyye saby
# Processing Record 46 of Set 3 | bereda
# Processing Record 47 of Set 3 | makakilo city
# Processing Record 48 of Set 3 | rawson
# Processing Record 49 of Set 3 | kruisfontein
# Processing Record 0 of Set 4 | alenquer
# Processing Record 1 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 2 of Set 4 | pangkalanbuun
# Processing Record 3 of Set 4 | keningau
# Processing Record 4 of Set 4 | kodiak
# Processing Record 5 of Set 4 | gussago
# Processing Record 6 of Set 4 | opuwo
# Processing Record 7 of Set 4 | galesong
# Processing Record 8 of Set 4 | ourem
# Processing Record 9 of Set 4 | nome
# Processing Record 10 of Set 4 | ribeira grande
# Processing Record 11 of Set 4 | fortuna
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | alghero
# Processing Record 14 of Set 4 | kahului
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | kapoeta
# Processing Record 17 of Set 4 | pringsewu
# Processing Record 18 of Set 4 | port lincoln
# Processing Record 19 of Set 4 | matara
# Processing Record 20 of Set 4 | hasaki
# Processing Record 21 of Set 4 | key largo
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | coquimbo
# Processing Record 24 of Set 4 | santander
# Processing Record 25 of Set 4 | belyy yar
# Processing Record 26 of Set 4 | katsuura
# Processing Record 27 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 4 | katobu
# Processing Record 29 of Set 4 | kisangani
# Processing Record 30 of Set 4 | steamboat springs
# Processing Record 31 of Set 4 | sidney
# Processing Record 32 of Set 4 | kudahuvadhoo
# Processing Record 33 of Set 4 | asfi
# Processing Record 34 of Set 4 | naurskaya
# Processing Record 35 of Set 4 | masterton
# Processing Record 36 of Set 4 | touros
# Processing Record 37 of Set 4 | paracatu
# Processing Record 38 of Set 4 | namibe
# Processing Record 39 of Set 4 | jumla
# Processing Record 40 of Set 4 | palmer
# Processing Record 41 of Set 4 | nemuro
# Processing Record 42 of Set 4 | port-gentil
# Processing Record 43 of Set 4 | chokurdakh
# Processing Record 44 of Set 4 | havelock
# Processing Record 45 of Set 4 | mandalgovi
# Processing Record 46 of Set 4 | qaqortoq
# Processing Record 47 of Set 4 | kemptville
# Processing Record 48 of Set 4 | lac du bonnet
# Processing Record 49 of Set 4 | hilo
# Processing Record 0 of Set 5 | sao filipe
# Processing Record 1 of Set 5 | pisco
# Processing Record 2 of Set 5 | christchurch
# Processing Record 3 of Set 5 | maragogi
# Processing Record 4 of Set 5 | moshi
# Processing Record 5 of Set 5 | atar
# Processing Record 6 of Set 5 | vila franca do campo
# Processing Record 7 of Set 5 | dunedin
# Processing Record 8 of Set 5 | biltine
# Processing Record 9 of Set 5 | dikson
# Processing Record 10 of Set 5 | kuching
# Processing Record 11 of Set 5 | mahebourg
# Processing Record 12 of Set 5 | seoul
# Processing Record 13 of Set 5 | faanui
# Processing Record 14 of Set 5 | sinjar
# Processing Record 15 of Set 5 | henties bay
# Processing Record 16 of Set 5 | emilio carranza
# Processing Record 17 of Set 5 | yakeshi
# Processing Record 18 of Set 5 | contamana
# Processing Record 19 of Set 5 | ahipara
# Processing Record 20 of Set 5 | bilibino
# Processing Record 21 of Set 5 | ano mera
# Processing Record 22 of Set 5 | naliya
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | comodoro rivadavia
# Processing Record 25 of Set 5 | georgetown
# Processing Record 26 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 27 of Set 5 | meulaboh
# Processing Record 28 of Set 5 | alofi
# Processing Record 29 of Set 5 | goure
# Processing Record 30 of Set 5 | ternate
# Processing Record 31 of Set 5 | indramayu
# Processing Record 32 of Set 5 | blyth
# Processing Record 33 of Set 5 | qasigiannguit
# Processing Record 34 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 5 | komyshuvakha
# Processing Record 36 of Set 5 | narsaq
# Processing Record 37 of Set 5 | okhotsk
# Processing Record 38 of Set 5 | ahuimanu
# Processing Record 39 of Set 5 | provideniya
# Processing Record 40 of Set 5 | havoysund
# Processing Record 41 of Set 5 | harlingen
# Processing Record 42 of Set 5 | merauke
# Processing Record 43 of Set 5 | saint-philippe
# Processing Record 44 of Set 5 | little current
# Processing Record 45 of Set 5 | raub
# Processing Record 46 of Set 5 | taoudenni
# Processing Record 47 of Set 5 | tutoia
# Processing Record 48 of Set 5 | ratnagiri
# Processing Record 49 of Set 5 | biak
# Processing Record 0 of Set 6 | robertsport
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | storforshei
# Processing Record 3 of Set 6 | ituni
# City not found. Skipping...
# Processing Record 4 of Set 6 | inuvik
# Processing Record 5 of Set 6 | tokmak
# Processing Record 6 of Set 6 | tema
# Processing Record 7 of Set 6 | mendota heights
# Processing Record 8 of Set 6 | itoman
# Processing Record 9 of Set 6 | puma
# Processing Record 10 of Set 6 | parakou
# Processing Record 11 of Set 6 | pangnirtung
# Processing Record 12 of Set 6 | udachnyy
# Processing Record 13 of Set 6 | shubarkuduk
# Processing Record 14 of Set 6 | berlevag
# Processing Record 15 of Set 6 | ucluelet
# Processing Record 16 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 17 of Set 6 | batagay-alyta
# Processing Record 18 of Set 6 | meadow lake
# Processing Record 19 of Set 6 | juruti
# Processing Record 20 of Set 6 | sitka
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | udalguri
# Processing Record 23 of Set 6 | fallon
# Processing Record 24 of Set 6 | pevek
# Processing Record 25 of Set 6 | mut
# Processing Record 26 of Set 6 | broken hill
# Processing Record 27 of Set 6 | fort wellington
# Processing Record 28 of Set 6 | quatre cocos
# Processing Record 29 of Set 6 | pangody
# Processing Record 30 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 6 | smithers
# Processing Record 32 of Set 6 | kirkenes
# Processing Record 33 of Set 6 | kintampo
# Processing Record 34 of Set 6 | arman
# Processing Record 35 of Set 6 | grants
# Processing Record 36 of Set 6 | ogdensburg
# Processing Record 37 of Set 6 | belle fourche
# Processing Record 38 of Set 6 | tucurui
# Processing Record 39 of Set 6 | koster
# Processing Record 40 of Set 6 | alice
# Processing Record 41 of Set 6 | penzance
# Processing Record 42 of Set 6 | lagoa
# Processing Record 43 of Set 6 | assiniboia
# Processing Record 44 of Set 6 | puri
# Processing Record 45 of Set 6 | saint george
# Processing Record 46 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 47 of Set 6 | port-cartier
# Processing Record 48 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 6 | afua
# Processing Record 0 of Set 7 | gorontalo
# Processing Record 1 of Set 7 | bollnas
# Processing Record 2 of Set 7 | mehamn
# Processing Record 3 of Set 7 | fort nelson
# Processing Record 4 of Set 7 | dubai
# Processing Record 5 of Set 7 | vestmannaeyjar
# Processing Record 6 of Set 7 | mugur-aksy
# Processing Record 7 of Set 7 | gravdal
# Processing Record 8 of Set 7 | ebebiyin
# Processing Record 9 of Set 7 | kailua
# Processing Record 10 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 7 | iturbe
# Processing Record 12 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 13 of Set 7 | bundaberg
# Processing Record 14 of Set 7 | pahrump
# Processing Record 15 of Set 7 | naze
# Processing Record 16 of Set 7 | prestea
# Processing Record 17 of Set 7 | hambantota
# Processing Record 18 of Set 7 | buchanan
# Processing Record 19 of Set 7 | esperance
# Processing Record 20 of Set 7 | mzimba
# Processing Record 21 of Set 7 | shumikha
# Processing Record 22 of Set 7 | khatanga
# Processing Record 23 of Set 7 | codrington
# Processing Record 24 of Set 7 | staryy nadym
# Processing Record 25 of Set 7 | sao paulo de olivenca
# Processing Record 26 of Set 7 | boca do acre
# Processing Record 27 of Set 7 | luanda
# Processing Record 28 of Set 7 | batticaloa
# Processing Record 29 of Set 7 | yulara
# Processing Record 30 of Set 7 | ituporanga
# Processing Record 31 of Set 7 | sikea
# City not found. Skipping...
# Processing Record 32 of Set 7 | xining
# Processing Record 33 of Set 7 | ribeira brava
# Processing Record 34 of Set 7 | vila do maio
# Processing Record 35 of Set 7 | corinto
# Processing Record 36 of Set 7 | liberal
# Processing Record 37 of Set 7 | la ferte-bernard
# Processing Record 38 of Set 7 | skhisma
# Processing Record 39 of Set 7 | lalmohan
# Processing Record 40 of Set 7 | laguna
# Processing Record 41 of Set 7 | alta floresta
# Processing Record 42 of Set 7 | aripuana
# Processing Record 43 of Set 7 | oum hadjer
# Processing Record 44 of Set 7 | mason city
# Processing Record 45 of Set 7 | tura
# Processing Record 46 of Set 7 | bandarbeyla
# Processing Record 47 of Set 7 | bac
# Processing Record 48 of Set 7 | iskateley
# Processing Record 49 of Set 7 | pampa
# Processing Record 0 of Set 8 | zhigalovo
# Processing Record 1 of Set 8 | vilhena
# Processing Record 2 of Set 8 | tilichiki
# Processing Record 3 of Set 8 | paita
# Processing Record 4 of Set 8 | brainerd
# Processing Record 5 of Set 8 | deputatskiy
# Processing Record 6 of Set 8 | coihaique
# Processing Record 7 of Set 8 | san matias
# Processing Record 8 of Set 8 | isangel
# Processing Record 9 of Set 8 | vakhrushev
# Processing Record 10 of Set 8 | sao joao da barra
# Processing Record 11 of Set 8 | amuntai
# Processing Record 12 of Set 8 | slyudyanka
# Processing Record 13 of Set 8 | copiapo
# Processing Record 14 of Set 8 | vila velha
# Processing Record 15 of Set 8 | kuldur
# Processing Record 16 of Set 8 | teacapan
# Processing Record 17 of Set 8 | ajaccio
# Processing Record 18 of Set 8 | bure
# Processing Record 19 of Set 8 | buta
# Processing Record 20 of Set 8 | chapais
# Processing Record 21 of Set 8 | ilulissat
# Processing Record 22 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | samarai
# Processing Record 25 of Set 8 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 26 of Set 8 | chuy
# Processing Record 27 of Set 8 | grindavik
# Processing Record 28 of Set 8 | dawei
# Processing Record 29 of Set 8 | saint combs
# City not found. Skipping...
# Processing Record 30 of Set 8 | trairi
# Processing Record 31 of Set 8 | egvekinot
# Processing Record 32 of Set 8 | antalaha
# Processing Record 33 of Set 8 | qafsah
# City not found. Skipping...
# Processing Record 34 of Set 8 | rolla
# Processing Record 35 of Set 8 | zhangye
# Processing Record 36 of Set 8 | great bend
# Processing Record 37 of Set 8 | nikolayevka
# Processing Record 38 of Set 8 | dudinka
# Processing Record 39 of Set 8 | skibbereen
# Processing Record 40 of Set 8 | oussouye
# Processing Record 41 of Set 8 | muros
# Processing Record 42 of Set 8 | ketchikan
# Processing Record 43 of Set 8 | kaitangata
# Processing Record 44 of Set 8 | rumford
# Processing Record 45 of Set 8 | ulladulla
# Processing Record 46 of Set 8 | panguipulli
# Processing Record 47 of Set 8 | hurricane
# Processing Record 48 of Set 8 | bandar-e lengeh
# Processing Record 49 of Set 8 | ambilobe
# Processing Record 0 of Set 9 | camacha
# Processing Record 1 of Set 9 | worcester
# Processing Record 2 of Set 9 | ugoofaaru
# Processing Record 3 of Set 9 | saint-georges
# Processing Record 4 of Set 9 | talnakh
# Processing Record 5 of Set 9 | codajas
# Processing Record 6 of Set 9 | utinga
# Processing Record 7 of Set 9 | buala
# Processing Record 8 of Set 9 | cherskiy
# Processing Record 9 of Set 9 | sanquelim
# Processing Record 10 of Set 9 | nagato
# Processing Record 11 of Set 9 | rondonopolis
# Processing Record 12 of Set 9 | labuan
# Processing Record 13 of Set 9 | rancho palos verdes
# Processing Record 14 of Set 9 | los llanos de aridane
# Processing Record 15 of Set 9 | huilong
# Processing Record 16 of Set 9 | formoso do araguaia
# City not found. Skipping...
# Processing Record 17 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 9 | fort frances
# Processing Record 19 of Set 9 | haines junction
# Processing Record 20 of Set 9 | brae
# Processing Record 21 of Set 9 | kyra
# Processing Record 22 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 9 | tuatapere
# Processing Record 24 of Set 9 | dingle
# Processing Record 25 of Set 9 | mount gambier
# Processing Record 26 of Set 9 | sobolevo
# Processing Record 27 of Set 9 | yaan
# Processing Record 28 of Set 9 | klaksvik
# Processing Record 29 of Set 9 | sabang
# Processing Record 30 of Set 9 | racine
# Processing Record 31 of Set 9 | manokwari
# Processing Record 32 of Set 9 | tarko-sale
# Processing Record 33 of Set 9 | ushtobe
# Processing Record 34 of Set 9 | liepaja
# Processing Record 35 of Set 9 | innisfail
# Processing Record 36 of Set 9 | garissa
# Processing Record 37 of Set 9 | keansburg
# Processing Record 38 of Set 9 | norsup
# Processing Record 39 of Set 9 | cayenne
# Processing Record 40 of Set 9 | mitchell
# Processing Record 41 of Set 9 | matamoros
# Processing Record 42 of Set 9 | nouakchott
# Processing Record 43 of Set 9 | nishihara
# Processing Record 44 of Set 9 | port hawkesbury
# Processing Record 45 of Set 9 | rodniki
# Processing Record 46 of Set 9 | ivanteyevka
# Processing Record 47 of Set 9 | bac lieu
# Processing Record 48 of Set 9 | carbondale
# Processing Record 49 of Set 9 | bechem
# Processing Record 0 of Set 10 | vilyuysk
# Processing Record 1 of Set 10 | kawerau
# Processing Record 2 of Set 10 | goderich
# Processing Record 3 of Set 10 | asind
# Processing Record 4 of Set 10 | road town
# Processing Record 5 of Set 10 | skjervoy
# Processing Record 6 of Set 10 | gelibolu
# Processing Record 7 of Set 10 | leiyang
# Processing Record 8 of Set 10 | launceston
# Processing Record 9 of Set 10 | wladyslawowo
# Processing Record 10 of Set 10 | alyangula
# Processing Record 11 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 10 | coolum beach
# Processing Record 13 of Set 10 | sioux lookout
# Processing Record 14 of Set 10 | novokubansk
# Processing Record 15 of Set 10 | willowmore
# Processing Record 16 of Set 10 | pontarlier
# Processing Record 17 of Set 10 | xichang
# Processing Record 18 of Set 10 | wagar
# Processing Record 19 of Set 10 | aseri
# Processing Record 20 of Set 10 | lanivtsi
# Processing Record 21 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 10 | emsdetten
# Processing Record 23 of Set 10 | fairbanks
# Processing Record 24 of Set 10 | addis abeba
# Processing Record 25 of Set 10 | arua
# Processing Record 26 of Set 10 | dongsheng
# Processing Record 27 of Set 10 | la paz
# Processing Record 28 of Set 10 | kavaratti
# Processing Record 29 of Set 10 | soyo
# Processing Record 30 of Set 10 | kamskiye polyany
# Processing Record 31 of Set 10 | toyo
# Processing Record 32 of Set 10 | perelyub
# Processing Record 33 of Set 10 | auki
# Processing Record 34 of Set 10 | nalut
# Processing Record 35 of Set 10 | lagunas
# Processing Record 36 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 38 of Set 10 | san lazaro
# Processing Record 39 of Set 10 | sur
# Processing Record 40 of Set 10 | omsukchan
# Processing Record 41 of Set 10 | ardmore
# Processing Record 42 of Set 10 | bella union
# Processing Record 43 of Set 10 | methoni
# Processing Record 44 of Set 10 | voh
# Processing Record 45 of Set 10 | olinda
# Processing Record 46 of Set 10 | ballina
# Processing Record 47 of Set 10 | nerchinskiy zavod
# Processing Record 48 of Set 10 | richards bay
# Processing Record 49 of Set 10 | maku
# Processing Record 0 of Set 11 | de aar
# Processing Record 1 of Set 11 | montepuez
# Processing Record 2 of Set 11 | san blas
# Processing Record 3 of Set 11 | san quintin
# Processing Record 4 of Set 11 | pacific grove
# Processing Record 5 of Set 11 | vaitape
# Processing Record 6 of Set 11 | sohag
# Processing Record 7 of Set 11 | prince rupert
# Processing Record 8 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 11 | san carlos de bariloche
# Processing Record 10 of Set 11 | semme
# Processing Record 11 of Set 11 | shaunavon
# Processing Record 12 of Set 11 | labuhan
# Processing Record 13 of Set 11 | faya
# Processing Record 14 of Set 11 | diebougou
# Processing Record 15 of Set 11 | ambulu
# Processing Record 16 of Set 11 | ashqelon
# Processing Record 17 of Set 11 | teguldet
# Processing Record 18 of Set 11 | sucila
# Processing Record 19 of Set 11 | avera
# Processing Record 20 of Set 11 | la baule-escoublac
# Processing Record 21 of Set 11 | oranjemund
# Processing Record 22 of Set 11 | la ronge
# Processing Record 23 of Set 11 | port macquarie
# Processing Record 24 of Set 11 | grand gaube
# Processing Record 25 of Set 11 | demba
# Processing Record 26 of Set 11 | aqtobe
# Processing Record 27 of Set 11 | marawi
# Processing Record 28 of Set 11 | tessalit
# Processing Record 29 of Set 11 | kutum
# Processing Record 30 of Set 11 | bonavista
# Processing Record 31 of Set 11 | marsh harbour
# Processing Record 32 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 33 of Set 11 | ye
# City not found. Skipping...
# Processing Record 34 of Set 11 | angoche
# Processing Record 35 of Set 11 | betsiamites
# Processing Record 36 of Set 11 | dubbo
# Processing Record 37 of Set 11 | warri
# Processing Record 38 of Set 11 | lata
# Processing Record 39 of Set 11 | sterling
# Processing Record 40 of Set 11 | yangmei
# Processing Record 41 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 42 of Set 11 | amahai
# Processing Record 43 of Set 11 | pasni
# Processing Record 44 of Set 11 | bulawayo
# Processing Record 45 of Set 11 | maloy
# Processing Record 46 of Set 11 | cairns
# Processing Record 47 of Set 11 | elizabeth city
# Processing Record 48 of Set 11 | mastic beach
# Processing Record 49 of Set 11 | martapura
# Processing Record 0 of Set 12 | talcahuano
# Processing Record 1 of Set 12 | kimbe
# Processing Record 2 of Set 12 | tezu
# Processing Record 3 of Set 12 | mogadishu
# Processing Record 4 of Set 12 | orgita
# Processing Record 5 of Set 12 | muyezerskiy
# Processing Record 6 of Set 12 | keti bandar
# Processing Record 7 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 8 of Set 12 | cockburn town
# Processing Record 9 of Set 12 | santa rosa
# Processing Record 10 of Set 12 | usinsk
# Processing Record 11 of Set 12 | agadir
# Processing Record 12 of Set 12 | palembang
# Processing Record 13 of Set 12 | ouadda
# Processing Record 14 of Set 12 | bani
# Processing Record 15 of Set 12 | soubre
# Processing Record 16 of Set 12 | ostrovnoy
# Processing Record 17 of Set 12 | mana
# Processing Record 18 of Set 12 | hohhot
# Processing Record 19 of Set 12 | bathsheba
# Processing Record 20 of Set 12 | mahuva
# Processing Record 21 of Set 12 | blind river
# Processing Record 22 of Set 12 | barabai
# Processing Record 23 of Set 12 | birjand
# Processing Record 24 of Set 12 | zwedru
# Processing Record 25 of Set 12 | denpasar
# Processing Record 26 of Set 12 | alice springs
# Processing Record 27 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 12 | sorkjosen
# Processing Record 29 of Set 12 | moree
# Processing Record 30 of Set 12 | riyadh
# Processing Record 31 of Set 12 | monrovia
# Processing Record 32 of Set 12 | dharchula
# Processing Record 33 of Set 12 | veseloyarsk
# Processing Record 34 of Set 12 | kajaani
# Processing Record 35 of Set 12 | kathmandu
# Processing Record 36 of Set 12 | mandurah
# Processing Record 37 of Set 12 | dhangadhi
# Processing Record 38 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 39 of Set 12 | portland
# Processing Record 40 of Set 12 | mainpuri
# Processing Record 41 of Set 12 | nouadhibou
# Processing Record 42 of Set 12 | pindiga
# Processing Record 43 of Set 12 | inhambane
# Processing Record 44 of Set 12 | narodychi
# Processing Record 45 of Set 12 | koungou
# Processing Record 46 of Set 12 | newcastle
# Processing Record 47 of Set 12 | necochea
# Processing Record 48 of Set 12 | imbituba
# Processing Record 49 of Set 12 | shache
# Processing Record 0 of Set 13 | dong hoi
# Processing Record 1 of Set 13 | cordeiropolis
# Processing Record 2 of Set 13 | barkhan
# Processing Record 3 of Set 13 | turan
# Processing Record 4 of Set 13 | khuzhir
# Processing Record 5 of Set 13 | morondava
# Processing Record 6 of Set 13 | kilindoni
# Processing Record 7 of Set 13 | pochutla
# Processing Record 8 of Set 13 | keuruu
# Processing Record 9 of Set 13 | viedma
# Processing Record 10 of Set 13 | panzhihua
# Processing Record 11 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 13 | lenoir city
# Processing Record 13 of Set 13 | trincomalee
# Processing Record 14 of Set 13 | shediac
# Processing Record 15 of Set 13 | sheridan
# Processing Record 16 of Set 13 | neka
# Processing Record 17 of Set 13 | nenjiang
# Processing Record 18 of Set 13 | tabou
# Processing Record 19 of Set 13 | kalabo
# Processing Record 20 of Set 13 | ahome
# Processing Record 21 of Set 13 | plettenberg bay
# Processing Record 22 of Set 13 | guaraniacu
# Processing Record 23 of Set 13 | walvis bay
# Processing Record 24 of Set 13 | yola
# Processing Record 25 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 13 | maromitsa
# Processing Record 27 of Set 13 | yanliang
# Processing Record 28 of Set 13 | bambous virieux
# Processing Record 29 of Set 13 | yerbogachen
# Processing Record 30 of Set 13 | akyab
# Processing Record 31 of Set 13 | clonakilty
# Processing Record 32 of Set 13 | joshimath
# Processing Record 33 of Set 13 | kushmurun
# Processing Record 34 of Set 13 | turbat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
cityDataDF=pd.DataFrame(cityList)

cityDataDF.count()
# Out:
# City          591
# Lat           591
# Lng           591
# Max Temp      591
# Humidity      591
# Cloudiness    591
# Wind Speed    591
# Country       591
# Date          591
# dtype: int64

# %%
cityDataDF.head(5)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  mae hong son  19.3003   97.9685     18.18        49           0
# 1       qaanaaq  77.4840  -69.3632    -12.32        45           0
# 2       ushuaia -54.8000  -68.3000      7.81        61          75
# 3         beira -19.8436   34.8389     25.08        89          37
# 4  port hedland -20.3167  118.5667     27.03        74         100
#
#    Wind Speed Country        Date
# 0        0.95      TH  1677960392
# 1        3.81      GL  1677960637
# 2        9.26      AR  1677960638
# 3        3.75      MZ  1677960638
# 4        3.09      AU  1677960639

# %%
cityDataDF.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
cityDataDF = pd.read_csv("output_data/cities.csv", index_col="City_ID")

cityDataDF.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        mae hong son  19.3003   97.9685     18.18        49           0
# 1             qaanaaq  77.4840  -69.3632    -12.32        45           0
# 2             ushuaia -54.8000  -68.3000      7.81        61          75
# 3               beira -19.8436   34.8389     25.08        89          37
# 4        port hedland -20.3167  118.5667     27.03        74         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.95      TH  1677960392
# 1              3.81      GL  1677960637
# 2              9.26      AR  1677960638
# 3              3.75      MZ  1677960638
# 4              3.09      AU  1677960639

# %%
plt.scatter(cityDataDF["Lat"],cityDataDF["Max Temp"])
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitude vs. Temperature (2022-10-18)")
plt.grid()
plt.savefig("output_data/Fig1.png")
plt.show()

# %%
plt.scatter(cityDataDF["Lat"],cityDataDF["Humidity"])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.grid()
plt.savefig("output_data/Fig2.png")
plt.show()

# %%
plt.scatter(cityDataDF["Lat"],cityDataDF["Cloudiness"])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.grid()
plt.savefig("output_data/Fig3.png")
plt.show()

# %%
plt.scatter(cityDataDF["Lat"],cityDataDF["Wind Speed"])
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Windspeed (2022-10-18)")
plt.grid()
plt.savefig("output_data/Fig4.png")
plt.show()

# %%
northern_hemi_df = cityDataDF.loc[(cityDataDF["Lat"] >= 0)]
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        mae hong son  19.3003   97.9685     18.18        49           0
# 1             qaanaaq  77.4840  -69.3632    -12.32        45           0
# 6               fukue  32.6881  128.8419     12.11        63           4
# 7               tiksi  71.6872  128.8694    -18.38       100         100
# 9              albany  42.6001  -73.9662      3.15        88         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.95      TH  1677960392
# 1              3.81      GL  1677960637
# 6              8.24      JP  1677960422
# 7              0.64      RU  1677960642
# 9              1.83      US  1677960644

# %%
(slope,intercept,rvalue,pvalue,stderr)=linregress(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"])
regress_values=northern_hemi_df["Lat"] * slope + intercept

plt.plot(northern_hemi_df["Lat"],regress_values,"r-")

correlation=st.pearsonr(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"]
 print(f"The r-value is: {correlation}")


plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.scatter(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"])
# Out:
#   File "C:\Users\Joynus.LAPTOP-7VGNIUR3\AppData\Local\Temp\ipykernel_40888\1071578668.py", line 7
#     print(f"The r-value is: {correlation}")
#     ^
# SyntaxError: invalid syntax

# %%
southern_hemi_df = cityDataDF.loc[(cityDataDF["Lat"] <= 0)]
southern_hemi_df.head()

# %%
(slope,intercept,rvalue,pvalue,stderr)=linregress(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"])
regress_values=southern_hemi_df["Lat"] * slope + intercept

plt.plot(southern_hemi_df["Lat"],regress_values,"r-")
correlation=st.pearsonr(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"]
print(f"The r-value is: {correlation}")

plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.scatter(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"])

# %%
(slope,intercept,rvalue,pvalue,stderr)=linregress(northern_hemi_df["Lat"],northern_hemi_df["Humidity"])
regress_values=northern_hemi_df["Lat"] * slope + intercept

plt.plot(northern_hemi_df["Lat"],regress_values,"r-")

correlation=st.pearsonr(northern_hemi_df["Lat"],northern_hemi_df["Humidity"]
print(f"The r-value is: {correlation}")

plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.scatter(northern_hemi_df["Lat"],northern_hemi_df["Humidity"])

# %%
(slope,intercept,rvalue,pvalue,stderr)=linregress(southern_hemi_df["Lat"],southern_hemi_df["Humidity"])
regress_values=southern_hemi_df["Lat"] * slope + intercept

plt.plot(southern_hemi_df["Lat"],regress_values,"r-")

correlation=st.pearsonr(southern_hemi_df["Lat"],southern_hemi_df["Humidity"]
print(f"The r-value is: {correlation}")

plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.scatter(southern_hemi_df["Lat"],southern_hemi_df["Humidity"])

# %%
(slope,intercept,rvalue,pvalue,stderr)=linregress(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"])
regress_values=northern_hemi_df["Lat"] * slope + intercept

plt.plot(northern_hemi_df["Lat"],regress_values,"r-")

correlation=st.pearsonr(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"]
print(f"The r-value is: {correlation}")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.scatter(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"])

# %%
(slope,intercept,rvalue,pvalue,stderr)=linregress(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"])
regress_values=southern_hemi_df["Lat"] * slope + intercept

plt.plot(southern_hemi_df["Lat"],regress_values,"r-")

correlation=st.pearsonr(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"]
print(f"The r-value is: {correlation}")

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.scatter(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"])

# %%
(slope,intercept,rvalue,pvalue,stderr)=linregress(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"])
regress_values=northern_hemi_df["Lat"] * slope + intercept

plt.plot(northern_hemi_df["Lat"],regress_values,"r-")

correlation=st.pearsonr(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"]
print(f"The r-value is: {correlation}")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

# %%
(slope,intercept,rvalue,pvalue,stderr)=linregress(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"])
regress_values=southern_hemi_df["Lat"] * slope + intercept

plt.plot(southern_hemi_df["Lat"],regress_values,"r-")
correlation=st.pearsonr(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"]
print(f"The r-value is: {correlation}")

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.scatter(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"])
